# %% [markdown]
# ### Test data loader resampling function

# %%
# example asensory trial
from tests.test_data_handling_functions import _test_data_loader_resampling
# %matplotlib inline
_test_data_loader_resampling(TRIAL_ID='20160525.Fly1.1.10Hz')
# Out:
# /Users/rkp/anaconda/envs/py2/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
# example closed-loop trial (old)
from tests.test_data_handling_functions import _test_data_loader_resampling
# %matplotlib inline
_test_data_loader_resampling(TRIAL_ID='20160904.Fly6.7.10Hz Closed Loop')

# %%
# example closed-loop trial (new)
from tests.test_data_handling_functions import _test_data_loader_resampling
# %matplotlib inline
_test_data_loader_resampling(TRIAL_ID='20170201.Fly2.3.10Hz Closed Loop')

# %%
# example open-loop periodic trial
from tests.test_data_handling_functions import _test_data_loader_resampling
# %matplotlib inline
_test_data_loader_resampling(TRIAL_ID='20170117.Fly1.5.10Hz Open Loop')
# Out:
# /Users/rkp/anaconda/envs/py2/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
# example closed-loop-white-noise trial
from tests.test_data_handling_functions import _test_data_loader_resampling
# %matplotlib inline
_test_data_loader_resampling(TRIAL_ID='20170330.Fly1.4.10Hz Closed Loop White')

# %%
# %matplotlib inline
from tests.test_data_handling_functions import _test_air_tube_sign_is_consistent

_test_air_tube_sign_is_consistent(
    TRIAL_CLOSED_LOOP='20170201.Fly2.3.10Hz Closed Loop',
    TRIAL_CLOSED_LOOP_WHITE='20170330.Fly1.4.10Hz Closed Loop White')
# Out:
# /Users/rkp/anaconda/envs/py2/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
# %matplotlib inline
from tests.test_data_handling_functions import _test_air_tube_sign_is_consistent

_test_air_tube_sign_is_consistent(
    TRIAL_CLOSED_LOOP='20170201.Fly2.3.10Hz Closed Loop',
    TRIAL_CLOSED_LOOP_WHITE='20170330.Fly1.4.10Hz Closed Loop White')
# Out:
# /Users/rkp/anaconda/envs/py2/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
import pytest

pytest.main(['tests/test_data_handling_functions.py']);
pytest.main(['tests/test_metrics.py']);
pytest.main(['tests/test_models.py']);
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 2.7.13, pytest-3.0.5, py-1.4.32, pluggy-0.4.0
# rootdir: /Users/rkp/Dropbox/Repositories/mushroom_mushroom, inifile:
# collected 4 items
#
# tests/test_data_handling_functions.py ....
#
# =========================== 4 passed in 0.80 seconds ===========================
# ============================= test session starts ==============================
# platform darwin -- Python 2.7.13, pytest-3.0.5, py-1.4.32, pluggy-0.4.0
# rootdir: /Users/rkp/Dropbox/Repositories/mushroom_mushroom, inifile:
# collected 5 items
#
# tests/test_metrics.py .....
#
# =========================== 5 passed in 0.42 seconds ===========================
# ============================= test session starts ==============================
# platform darwin -- Python 2.7.13, pytest-3.0.5, py-1.4.32, pluggy-0.4.0
# rootdir: /Users/rkp/Dropbox/Repositories/mushroom_mushroom, inifile:
# collected 1 items
#
# ...

# %%
import pytest

pytest.main(['tests/test_coherence.py'])
pytest.main(['tests/test_model_comparison.py']);
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 2.7.13, pytest-3.0.5, py-1.4.32, pluggy-0.4.0
# rootdir: /Users/rkp/Dropbox/Repositories/mushroom_mushroom, inifile:
# collected 14 items
#
# tests/test_coherence.py ..
# tests/test_data_handling_functions.py ....
# tests/test_metrics.py .....
# tests/test_model_comparison.py .
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!! KeyboardInterrupt !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# to show a full traceback on KeyboardInterrupt use --fulltrace
# /Users/rkp/anaconda/envs/py2/lib/python2.7/site-packages/numpy/core/numerictypes.py:950: KeyboardInterrupt
# ========================== 12 passed in 39.43 seconds ==========================
